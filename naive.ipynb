# %% [markdown]
# <a href="https://colab.research.google.com/github/Krishnapriya-TP/ML-projects/blob/main/naive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer
df=pd.read_csv("/content/owid-covid-data.csv")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-47-7923608a15da> in <module>
#       3 import numpy as np
#       4 from sklearn.impute import SimpleImputer
# ----> 5 df=pd.read_csv("/content/owid-covid-data.csv")
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
print(df.shape)
# Out:
# (227186, 64)

# %%
print(df.head)
# Out:
# <bound method NDFrame.head of        iso_code      continent     location        date  total_cases  \
# 0           AFG           Asia  Afghanistan  2020-02-24          5.0
# 1           AFG           Asia  Afghanistan  2020-02-25          5.0
# 2           AFG           Asia  Afghanistan  2020-02-26          5.0
# 3           AFG           Asia  Afghanistan  2020-02-27          5.0
# 4           AFG           Asia  Afghanistan  2020-02-28          5.0
# ...         ...            ...          ...         ...          ...
# 227181      URY  South America      Uruguay  2020-09-25       1967.0
# 227182      URY  South America      Uruguay  2020-09-26       1998.0
# 227183      URY  South America      Uruguay  2020-09-27       2008.0
# 227184      URY  South America      Uruguay  2020-09-28       2010.0
# 227185      URY  South America      Uruguay  2020-09-29       2033.0
#
#         new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# ...

# %%
print(df.tail)
# Out:
# <bound method NDFrame.tail of        iso_code      continent     location        date  total_cases  \
# 0           AFG           Asia  Afghanistan  2020-02-24          5.0
# 1           AFG           Asia  Afghanistan  2020-02-25          5.0
# 2           AFG           Asia  Afghanistan  2020-02-26          5.0
# 3           AFG           Asia  Afghanistan  2020-02-27          5.0
# 4           AFG           Asia  Afghanistan  2020-02-28          5.0
# ...         ...            ...          ...         ...          ...
# 227181      URY  South America      Uruguay  2020-09-25       1967.0
# 227182      URY  South America      Uruguay  2020-09-26       1998.0
# 227183      URY  South America      Uruguay  2020-09-27       2008.0
# 227184      URY  South America      Uruguay  2020-09-28       2010.0
# 227185      URY  South America      Uruguay  2020-09-29       2033.0
#
#         new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# ...

# %%
print(df.columns)
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_cases_smoothed_per_million', 'total_deaths_per_million',
#        'new_deaths_per_million', 'new_deaths_smoothed_per_million',
#        'reproduction_rate', 'icu_patients', 'icu_patients_per_million',
#        'hosp_patients', 'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
#        'new_vaccinations', 'new_vaccinations_smoothed',
# ...

# %%
df.describe()
# Out:
#         total_cases     new_cases  new_cases_smoothed  total_deaths  \
# count  2.147030e+05  2.143940e+05        2.132490e+05  1.969290e+05
# mean   3.747031e+06  9.725972e+03        9.752038e+03  6.010359e+04
# std    1.999632e+07  6.204685e+04        6.018804e+04  2.503751e+05
# min    1.000000e+00  0.000000e+00        0.000000e+00  1.000000e+00
# 25%    5.090000e+03  0.000000e+00        5.857000e+00  1.160000e+02
# 50%    5.485600e+04  4.900000e+01        9.085700e+01  1.195000e+03
# 75%    5.806090e+05  9.360000e+02        1.120714e+03  1.061200e+04
# max    4.023756e+08  2.851878e+06        2.347186e+06  2.739589e+06
#
#           new_deaths  new_cases_smoothed_per_million  \
# count  196840.000000                   212228.000000
# mean      106.120240                      191.424086
# std       494.786127                      677.142435
# min         0.000000                        0.000000
# 25%         0.000000                        1.337000
# ...

# %%
df.drop(['new_cases_smoothed'],axis=1,inplace=True)
df
# Out:
#        iso_code      continent     location        date  total_cases  \
# 0           AFG           Asia  Afghanistan  2020-02-24          5.0
# 1           AFG           Asia  Afghanistan  2020-02-25          5.0
# 2           AFG           Asia  Afghanistan  2020-02-26          5.0
# 3           AFG           Asia  Afghanistan  2020-02-27          5.0
# 4           AFG           Asia  Afghanistan  2020-02-28          5.0
# ...         ...            ...          ...         ...          ...
# 227181      URY  South America      Uruguay  2020-09-25       1967.0
# 227182      URY  South America      Uruguay  2020-09-26       1998.0
# 227183      URY  South America      Uruguay  2020-09-27       2008.0
# 227184      URY  South America      Uruguay  2020-09-28       2010.0
# 227185      URY  South America      Uruguay  2020-09-29       2033.0
#
#         new_cases  total_deaths  new_deaths  new_cases_smoothed_per_million  \
# ...

# %%
df.drop(['new_deaths_smoothed','new_cases_per_million','total_cases_per_million'],axis=1,inplace=True)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-42-b09a5207bb2d> in <module>
# ----> 1 df.drop(['new_deaths_smoothed','new_cases_per_million','total_cases_per_million'],axis=1,inplace=True)
#       2 df
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4911             level=level,
#    4912             inplace=inplace,
# -> 4913             errors=errors,
#    4914         )
#    4915
#
# ...
